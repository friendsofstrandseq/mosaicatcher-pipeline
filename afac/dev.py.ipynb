# %%
import pandas as pd
import os

l = [
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20303_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20305_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20306_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20307_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20308_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20309_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20310_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20312_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20314_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20315_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20317_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20318_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20320_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20321_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20322_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20323_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20325_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20327_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20329_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20330_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20332_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20334_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20335_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20336_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20337_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20340_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20341_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20344_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20346_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20347_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20349_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20352_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20356_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20357_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20361_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20362_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20363_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20364_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20365_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20366_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20367_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20368_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20369_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20371_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20372_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20374_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20377_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20380_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20381_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20382_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20383_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20384_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20386_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20390_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20391_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20392_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20393_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20394_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20395_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20502_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20505_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20508_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20513_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20514_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20519_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20523_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20530_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20533_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20534_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20535_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20536_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20538_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20540_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20541_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20545_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20547_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20548_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20557_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20565_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20566_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20572_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20573_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20574_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20582_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20586_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20590_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20591_CREs_2kb.tab",
    "/g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/TAllPDX6340p6RELs1p1xPE20594_CREs_2kb.tab",
]

l_df = list()

l_df.append(
    pd.read_csv(
        sorted(list(l))[0],
        sep="\t",
        names=[
            "'chr'",
            "'start'",
            "'end'",
            "Feature",
            "'{file}'".format(file=os.path.basename(sorted(list(l))[0])).replace(".tab", ".bam"),
        ],
    )[["'chr'", "'start'", "'end'"]]
)

for file in sorted(list(l)):
    print(file)
    l_df.extend(
            pd.read_csv(
                file,
                nrows=50000,
                sep="\t",
                names=[
                    "'chr'",
                    "'start'",
                    "'end'",
                    "Feature",
                    "'{file}'".format(file=os.path.basename(file)).replace(".tab", ".bam"),
                ],
            )[["'{file}'".format(file=os.path.basename(file)).replace(".tab", ".bam")]]
    )
# print(len(l_df))
pd.concat(l_df, axis=1)

# pd.concat(l_df, axis=1).to_csv(snakemake.output.tab, sep="\t", index=False)
# Out:
# /g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20303_CREs_2kb.tab
# /g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20305_CREs_2kb.tab
# /g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20306_CREs_2kb.tab
# /g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20307_CREs_2kb.tab
# /g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20308_CREs_2kb.tab
# /g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20309_CREs_2kb.tab
# /g/korbel/Costea/Computational/StrandSeq/P6_Rel/TAllPDX6340p6REL/scNOVA_result/count_reads_CREs/PDX6340rel2PE20310_CREs_2kb.tab
# ...
