# %%
import tensorflow as tf
# Out:
# /g/korbel2/weber/miniconda3/envs/tf_jup/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /g/korbel2/weber/miniconda3/envs/tf_jup/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /g/korbel2/weber/miniconda3/envs/tf_jup/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
tf.__version__
# Out:
# '1.14.0'

# %%
import tensorflow as tf

# Load the saved model
saved_model_path = "/g/korbel2/weber/workspace/StrandSeq_workspace/STABLE/mosaicatcher-pipeline-old/workflow/data/scNOVA/models_CNN/DNN_train20_chr1.h5"
model = tf.keras.models.load_model(saved_model_path)
print(model.tensorflow_version)  # This attribute might be available in some cases
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2636281/2485009892.py in <module>
#       3 # Load the saved model
#       4 saved_model_path = "/g/korbel2/weber/workspace/StrandSeq_workspace/STABLE/mosaicatcher-pipeline-old/workflow/data/scNOVA/models_CNN/DNN_train20_chr1.h5"
# ----> 5 model = tf.keras.models.load_model(saved_model_path)
#       6 print(model.tensorflow_version)  # This attribute might be available in some cases
#
# /g/korbel2/weber/miniconda3/envs/tf_jup/lib/python3.7/site-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile)
#     144       h5py is not None and (
#     145           isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 146     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     147
#     148   if isinstance(filepath, six.string_types):
#
# ...

# %%
import tensorflow as tf

# Ensure you are in a TensorFlow v1 environment
tf.compat.v1.disable_v2_behavior()

# %%
# Load the model
model = tf.keras.models.load_model('/g/korbel2/weber/workspace/StrandSeq_workspace/STABLE/mosaicatcher-pipeline-old/workflow/data/scNOVA/models_CNN/DNN_train20_chr1.h5')

# Print the model summary to get insights
model.summary()

# Check if there are any hints about the TensorFlow version in the model configuration
config = model.get_config()
print(config)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2636281/1133309379.py in <module>
#       1 # Load the model
# ----> 2 model = tf.keras.models.load_model('/g/korbel2/weber/workspace/StrandSeq_workspace/STABLE/mosaicatcher-pipeline-old/workflow/data/scNOVA/models_CNN/DNN_train20_chr1.h5')
#       3
#       4 # Print the model summary to get insights
#       5 model.summary()
#
# /g/korbel2/weber/miniconda3/envs/tf_jup/lib/python3.7/site-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile)
#     144       h5py is not None and (
#     145           isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 146     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     147
#     148   if isinstance(filepath, six.string_types):
#
# ...
