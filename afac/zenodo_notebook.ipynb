# %%
# import requests
import os, sys

# %%
os.path.basename("/g/korbel2/weber/MosaiCatcher_files/snv_sites_to_genotype/TEST.vcf.gz")
# Out:
# 'TEST.vcf.gz'

# %%
os.path.dirname("/g/korbel2/weber/MosaiCatcher_files/snv_sites_to_genotype/TEST.vcf.gz")
# Out:
# '/g/korbel2/weber/MosaiCatcher_files/snv_sites_to_genotype'

# %%
ACCESS_TOKEN = "zC6VNgkbVpyfQ69KomNGdSMb6LGIPSSEbMdhlIFUlNBvkuBZXmJpofQoWnbO"

r = requests.get('https://sandbox.zenodo.org/api/deposit/depositions',
                  params={'access_token': ACCESS_TOKEN})
r.json()
# Out:
# [{'conceptdoi': '10.5072/zenodo.1073972',
#   'conceptrecid': '1073972',
#   'created': '2022-06-15T12:55:26.087120',
#   'doi': '10.5072/zenodo.1073973',
#   'doi_url': 'https://doi.org/10.5072/zenodo.1073973',
#   'files': [{'checksum': '85e26938a711e072e8b399b54467eb98',
#     'filename': 'ALL.chr1-22plusX_GRCh38_sites.20170504.renamedCHR.vcf.gz',
#     'filesize': 2388157736,
#     'id': '2617ca1e-003e-4da8-9a4b-deea27e84b6e',
#     'links': {'download': 'https://sandbox.zenodo.org/api/files/2a209c97-0178-48c0-82f5-c80242e42951/ALL.chr1-22plusX_GRCh38_sites.20170504.renamedCHR.vcf.gz',
#      'self': 'https://sandbox.zenodo.org/api/deposit/depositions/1073973/files/2617ca1e-003e-4da8-9a4b-deea27e84b6e'}},
#    {'checksum': 'a6da8681616c05eb542f1d91606a7b2f',
#     'filename': 'GCA_000001405.15_GRCh38_no_alt_analysis_set.fna',
#     'filesize': 3144230986,
#     'id': 'bfe1ec65-1278-4910-a60d-f843c39d7915',
# ...

# %%
headers = {"Content-Type": "application/json"}
params = {'access_token': ACCESS_TOKEN}
r = requests.post('https://sandbox.zenodo.org/api/deposit/depositions',
                   params=params,
                   json={},
                   # Headers are not necessary here since "requests" automatically
                   # adds "Content-Type: application/json", because we're using
                   # the "json=" keyword argument
                   # headers=headers,
                   headers=headers)
r.json()
# Out:
# {'conceptrecid': '1074720',
#  'created': '2022-06-20T07:39:05.293381+00:00',
#  'files': [],
#  'id': 1074721,
#  'links': {'bucket': 'https://sandbox.zenodo.org/api/files/bffe77ee-af09-4d0b-aed3-ca3b06057bbd',
#   'discard': 'https://sandbox.zenodo.org/api/deposit/depositions/1074721/actions/discard',
#   'edit': 'https://sandbox.zenodo.org/api/deposit/depositions/1074721/actions/edit',
#   'files': 'https://sandbox.zenodo.org/api/deposit/depositions/1074721/files',
#   'html': 'https://sandbox.zenodo.org/deposit/1074721',
#   'latest_draft': 'https://sandbox.zenodo.org/api/deposit/depositions/1074721',
#   'latest_draft_html': 'https://sandbox.zenodo.org/deposit/1074721',
#   'publish': 'https://sandbox.zenodo.org/api/deposit/depositions/1074721/actions/publish',
#   'self': 'https://sandbox.zenodo.org/api/deposit/depositions/1074721'},
#  'metadata': {'prereserve_doi': {'doi': '10.5072/zenodo.1074721',
#    'recid': 1074721}},
#  'modified': '2022-06-20T07:39:05.293392+00:00',
# ...

# %%
deposition_id = r.json()['id']
deposition_id
# Out:
# 1074721

# %%
bucket_url = r.json()["links"]["bucket"]
bucket_url
# Out:
# 'https://sandbox.zenodo.org/api/files/bffe77ee-af09-4d0b-aed3-ca3b06057bbd'

# %% [markdown]
# 1000G SNV VCF file

# %%
# New API
filename = "ALL.chr1-22plusX_GRCh38_sites.20170504.renamedCHR.vcf.gz"
path = "/g/korbel2/weber/MosaiCatcher_files/snv_sites_to_genotype/%s" % filename

# The target URL is a combination of the bucket link with the desired filename
# seperated by a slash.
with open(path, "rb") as fp:
    r = requests.put(
        "%s/%s" % (bucket_url, filename),
        data=fp,
        params=params,
    )
r.json()
# Out:
# {'mimetype': 'application/gzip',
#  'updated': '2022-06-20T07:39:05.715977+00:00',
#  'links': {'self': 'https://sandbox.zenodo.org/api/files/bffe77ee-af09-4d0b-aed3-ca3b06057bbd/ALL.chr1-22plusX_GRCh38_sites.20170504.renamedCHR.vcf.gz',
#   'version': 'https://sandbox.zenodo.org/api/files/bffe77ee-af09-4d0b-aed3-ca3b06057bbd/ALL.chr1-22plusX_GRCh38_sites.20170504.renamedCHR.vcf.gz?versionId=c1158176-cb27-4fb4-9352-804c453151d4',
#   'uploads': 'https://sandbox.zenodo.org/api/files/bffe77ee-af09-4d0b-aed3-ca3b06057bbd/ALL.chr1-22plusX_GRCh38_sites.20170504.renamedCHR.vcf.gz?uploads'},
#  'is_head': True,
#  'created': '2022-06-20T07:39:05.711179+00:00',
#  'checksum': 'md5:85e26938a711e072e8b399b54467eb98',
#  'version_id': 'c1158176-cb27-4fb4-9352-804c453151d4',
#  'delete_marker': False,
#  'key': 'ALL.chr1-22plusX_GRCh38_sites.20170504.renamedCHR.vcf.gz',
#  'size': 2388157736}

# %%
# New API
filename = "ALL.chr1-22plusX_GRCh38_sites.20170504.renamedCHR.vcf.gz.tbi"
path = "/g/korbel2/weber/MosaiCatcher_files/snv_sites_to_genotype/%s" % filename

# The target URL is a combination of the bucket link with the desired filename
# seperated by a slash.
with open(path, "rb") as fp:
    r = requests.put(
        "%s/%s" % (bucket_url, filename),
        data=fp,
        params=params,
    )
r.json()
# Out:
# {'mimetype': 'application/octet-stream',
#  'updated': '2022-06-20T07:39:33.862716+00:00',
#  'links': {'self': 'https://sandbox.zenodo.org/api/files/bffe77ee-af09-4d0b-aed3-ca3b06057bbd/ALL.chr1-22plusX_GRCh38_sites.20170504.renamedCHR.vcf.gz.tbi',
#   'version': 'https://sandbox.zenodo.org/api/files/bffe77ee-af09-4d0b-aed3-ca3b06057bbd/ALL.chr1-22plusX_GRCh38_sites.20170504.renamedCHR.vcf.gz.tbi?versionId=8645452a-574f-4f7f-8f0c-c245988a243c',
#   'uploads': 'https://sandbox.zenodo.org/api/files/bffe77ee-af09-4d0b-aed3-ca3b06057bbd/ALL.chr1-22plusX_GRCh38_sites.20170504.renamedCHR.vcf.gz.tbi?uploads'},
#  'is_head': True,
#  'created': '2022-06-20T07:39:33.857434+00:00',
#  'checksum': 'md5:62c1f372388bb7ecfe5e394c594e3589',
#  'version_id': '8645452a-574f-4f7f-8f0c-c245988a243c',
#  'delete_marker': False,
#  'key': 'ALL.chr1-22plusX_GRCh38_sites.20170504.renamedCHR.vcf.gz.tbi',
#  'size': 2355697}

# %% [markdown]
# GRCh38 Ref genome

# %%
# New API
filename = "GCA_000001405.15_GRCh38_no_alt_analysis_set.fna"
path = "/g/korbel2/weber/MosaiCatcher_files/refgenomes_human_local/%s" % filename

# The target URL is a combination of the bucket link with the desired filename
# seperated by a slash.
with open(path, "rb") as fp:
    r = requests.put(
        "%s/%s" % (bucket_url, filename),
        data=fp,
        params=params,
    )
r.json()
# Out:
# {'mimetype': 'application/octet-stream',
#  'updated': '2022-06-20T07:39:34.129669+00:00',
#  'links': {'self': 'https://sandbox.zenodo.org/api/files/bffe77ee-af09-4d0b-aed3-ca3b06057bbd/GCA_000001405.15_GRCh38_no_alt_analysis_set.fna',
#   'version': 'https://sandbox.zenodo.org/api/files/bffe77ee-af09-4d0b-aed3-ca3b06057bbd/GCA_000001405.15_GRCh38_no_alt_analysis_set.fna?versionId=73674162-d7ec-44df-8cc7-b357b35a889c',
#   'uploads': 'https://sandbox.zenodo.org/api/files/bffe77ee-af09-4d0b-aed3-ca3b06057bbd/GCA_000001405.15_GRCh38_no_alt_analysis_set.fna?uploads'},
#  'is_head': True,
#  'created': '2022-06-20T07:39:34.125133+00:00',
#  'checksum': 'md5:a6da8681616c05eb542f1d91606a7b2f',
#  'version_id': '73674162-d7ec-44df-8cc7-b357b35a889c',
#  'delete_marker': False,
#  'key': 'GCA_000001405.15_GRCh38_no_alt_analysis_set.fna',
#  'size': 3144230986}

# %%
# New API
filename = "GCA_000001405.15_GRCh38_no_alt_analysis_set.fna.fai"
path = "/g/korbel2/weber/MosaiCatcher_files/refgenomes_human_local/%s" % filename

# The target URL is a combination of the bucket link with the desired filename
# seperated by a slash.
with open(path, "rb") as fp:
    r = requests.put(
        "%s/%s" % (bucket_url, filename),
        data=fp,
        params=params,
    )
r.json()
# Out:
# {'mimetype': 'application/octet-stream',
#  'updated': '2022-06-20T07:40:06.049614+00:00',
#  'links': {'self': 'https://sandbox.zenodo.org/api/files/bffe77ee-af09-4d0b-aed3-ca3b06057bbd/GCA_000001405.15_GRCh38_no_alt_analysis_set.fna.fai',
#   'version': 'https://sandbox.zenodo.org/api/files/bffe77ee-af09-4d0b-aed3-ca3b06057bbd/GCA_000001405.15_GRCh38_no_alt_analysis_set.fna.fai?versionId=dce0054d-3a62-4a86-8aad-7d5225f3f67d',
#   'uploads': 'https://sandbox.zenodo.org/api/files/bffe77ee-af09-4d0b-aed3-ca3b06057bbd/GCA_000001405.15_GRCh38_no_alt_analysis_set.fna.fai?uploads'},
#  'is_head': True,
#  'created': '2022-06-20T07:40:06.043677+00:00',
#  'checksum': 'md5:5fddbc109c82980f9436aa5c21a57c61',
#  'version_id': 'dce0054d-3a62-4a86-8aad-7d5225f3f67d',
#  'delete_marker': False,
#  'key': 'GCA_000001405.15_GRCh38_no_alt_analysis_set.fna.fai',
#  'size': 7804}

# %% [markdown]
# BM510 BAM example data

# %%
# New API
filename = "TEST_EXAMPLE_DATA.zip"
path = "/g/korbel2/weber/workspace/mosaicatcher-update/workflow/%s" % filename

# The target URL is a combination of the bucket link with the desired filename
# seperated by a slash.
with open(path, "rb") as fp:
    r = requests.put(
        "%s/%s" % (bucket_url, filename),
        data=fp,
        params=params,
    )
r.json()
# Out:
# {'mimetype': 'application/zip',
#  'updated': '2022-06-20T07:40:33.593226+00:00',
#  'links': {'self': 'https://sandbox.zenodo.org/api/files/bffe77ee-af09-4d0b-aed3-ca3b06057bbd/TEST_EXAMPLE_DATA.zip',
#   'version': 'https://sandbox.zenodo.org/api/files/bffe77ee-af09-4d0b-aed3-ca3b06057bbd/TEST_EXAMPLE_DATA.zip?versionId=6bb8f092-7f74-4075-9161-e6ac4b26bf8f',
#   'uploads': 'https://sandbox.zenodo.org/api/files/bffe77ee-af09-4d0b-aed3-ca3b06057bbd/TEST_EXAMPLE_DATA.zip?uploads'},
#  'is_head': True,
#  'created': '2022-06-20T07:40:33.588833+00:00',
#  'checksum': 'md5:3fec0193909c4463d20a7896f5ca67b3',
#  'version_id': '6bb8f092-7f74-4075-9161-e6ac4b26bf8f',
#  'delete_marker': False,
#  'key': 'TEST_EXAMPLE_DATA.zip',
#  'size': 2795858441}

# %%
deposition_id
# Out:
# 1074721

# %%
import json
data = {
    'metadata': {
        'title': 'MosaiCatcher pipeline data',
        'upload_type': 'other',
        'description': 'RPE-BM510 BAM example data + External data to use in MosaiCatcher snakemake pipeline ; 1000G SNV site + GRCh38 Ref genome',
        'creators': [{'name': 'Weber, Thomas',
                      'affiliation': 'EMBL Heidelberg'}]
    }
}
r = requests.put('https://sandbox.zenodo.org/api/deposit/depositions/%s' % deposition_id,
                 params={'access_token': ACCESS_TOKEN}, data=json.dumps(data),
                 headers=headers)
r.status_code
r.json()
# Out:
# {'conceptrecid': '1074720',
#  'created': '2022-06-20T07:39:05.293381+00:00',
#  'doi': '',
#  'doi_url': 'https://doi.org/',
#  'files': [{'checksum': '85e26938a711e072e8b399b54467eb98',
#    'filename': 'ALL.chr1-22plusX_GRCh38_sites.20170504.renamedCHR.vcf.gz',
#    'filesize': 2388157736,
#    'id': '83679c15-11ab-420c-9c8f-5bd5441aaeab',
#    'links': {'download': 'https://sandbox.zenodo.org/api/files/bffe77ee-af09-4d0b-aed3-ca3b06057bbd/ALL.chr1-22plusX_GRCh38_sites.20170504.renamedCHR.vcf.gz',
#     'self': 'https://sandbox.zenodo.org/api/deposit/depositions/1074721/files/83679c15-11ab-420c-9c8f-5bd5441aaeab'}},
#   {'checksum': '62c1f372388bb7ecfe5e394c594e3589',
#    'filename': 'ALL.chr1-22plusX_GRCh38_sites.20170504.renamedCHR.vcf.gz.tbi',
#    'filesize': 2355697,
#    'id': 'be2a365e-7a84-459f-b2b9-f7c735a20d8f',
# ...

# %%
r = requests.post('https://sandbox.zenodo.org/api/deposit/depositions/%s/actions/publish' % deposition_id,
                  params={'access_token': ACCESS_TOKEN} )
r.json()
# Out:
# {'conceptdoi': '10.5072/zenodo.1074720',
#  'conceptrecid': '1074720',
#  'created': '2022-06-20T07:39:05.293381+00:00',
#  'doi': '10.5072/zenodo.1074721',
#  'doi_url': 'https://doi.org/10.5072/zenodo.1074721',
#  'files': [{'checksum': '85e26938a711e072e8b399b54467eb98',
#    'filename': 'ALL.chr1-22plusX_GRCh38_sites.20170504.renamedCHR.vcf.gz',
#    'filesize': 2388157736,
#    'id': '83679c15-11ab-420c-9c8f-5bd5441aaeab',
#    'links': {'download': 'https://sandbox.zenodo.org/api/files/bffe77ee-af09-4d0b-aed3-ca3b06057bbd/ALL.chr1-22plusX_GRCh38_sites.20170504.renamedCHR.vcf.gz',
#     'self': 'https://sandbox.zenodo.org/api/deposit/depositions/1074721/files/83679c15-11ab-420c-9c8f-5bd5441aaeab'}},
#   {'checksum': '62c1f372388bb7ecfe5e394c594e3589',
#    'filename': 'ALL.chr1-22plusX_GRCh38_sites.20170504.renamedCHR.vcf.gz.tbi',
#    'filesize': 2355697,
#    'id': 'be2a365e-7a84-459f-b2b9-f7c735a20d8f',
# ...
